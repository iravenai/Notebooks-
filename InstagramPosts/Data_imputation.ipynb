# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.array([[1, 2, np.nan, 4], 
                            [np.nan, np.nan, np.nan, np.nan], 
                            [9, 10, 11 , 12], 
                            [13, 14, 15, 16]]), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#       a     b     c     d
# 0   1.0   2.0   NaN   4.0
# 1   NaN   NaN   NaN   NaN
# 2   9.0  10.0  11.0  12.0
# 3  13.0  14.0  15.0  16.0

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer()
imputer.fit_transform(df)
# Out:
# array([[ 1.        ,  2.        , 13.        ,  4.        ],
#        [ 7.66666667,  8.66666667, 13.        , 10.66666667],
#        [ 9.        , 10.        , 11.        , 12.        ],
#        [13.        , 14.        , 15.        , 16.        ]])

# %%
from fancyimpute import IterativeImputer as MICE

MICE().fit_transform(df)

# %%
MICE().fit_transform(df)
# Out:
# array([[ 1.        ,  2.        ,  3.0000025 ,  4.        ],
#        [ 7.66666667,  8.66666667,  9.6666675 , 10.66666667],
#        [ 9.        , 10.        , 11.        , 12.        ],
#        [13.        , 14.        , 15.        , 16.        ]])
